# %%
import numpy as np
import pandas as pd
df = pd.read_csv('DeskTop/exl.csv')
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
pd.read_csv('DeskTop/exl2.csv',names=['a','b','c','d','message'])
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
names = ['a','b','c','d','message']
pd.read_csv('Desktop/exl2.csv',names=names,index_col='message')
# Out:
#          a   b   c   d
# message
# hello    1   2   3   4
# world    5   6   7   8
# foo      9  10  11  12

# %%
parsed = pd.read_csv('Desktop/csv_mindex.csv',
                    index_col=['key1','key2'])
parsed
# Out:
#            value  value2
# key1 key2
# one  a         1       2
#      b         3       4
#      c         5       6
#      d         7       8
# two  a         9      10
#      b        11      12
#      c        13      14
#      d        15      16

# %%
result = pd.read_csv('Desktop/ex5.csv')
result
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
pd.isnull(result)
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False  False   True  False    False
# 2      False  False  False  False  False    False

# %%
result = pd.read_csv('Desktop/ex5.csv',na_values=['2'])
result
# Out:
#   something  a     b     c   d message
# 0       one  1   NaN   3.0   4     NaN
# 1       two  5   6.0   NaN   8   world
# 2     three  9  10.0  11.0  12     foo

# %%
sentinels = {'message':['foo','NA'],'something':['two']}
pd.read_csv('Desktop/ex5.csv',na_values=sentinels)
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       NaN  5   6   NaN   8   world
# 2     three  9  10  11.0  12     NaN

# %%
data = pd.read_csv('Desktop/ex5.csv')
data
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
data.to_csv('Desktop/out.csv')

# %%
import sys
data.to_csv(sys.stdout,sep='|')
# Out:
# |something|a|b|c|d|message
# 0|one|1|2|3.0|4|
# 1|two|5|6||8|world
# 2|three|9|10|11.0|12|foo

# %%
data.to_csv(sys.stdout,na_rep='NULL')
# Out:
# ,something,a,b,c,d,message
# 0,one,1,2,3.0,4,NULL
# 1,two,5,6,NULL,8,world
# 2,three,9,10,11.0,12,foo

# %%
data.to_csv(sys.stdout,index=False,header=False)
# Out:
# one,1,2,3.0,4,
# two,5,6,,8,world
# three,9,10,11.0,12,foo

# %%
dates = pd.date_range('1/1/2000',periods=7)
ts = pd.Series(np.arange(7),index=dates)
ts.to_csv('Desktop/tseries.csv')
# Out:
# E:\Anaconda\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
dates = pd.date_range('1/1/2000',periods=7)
dates
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.Series(dates)
# Out:
# 0   2000-01-01
# 1   2000-01-02
# 2   2000-01-03
# 3   2000-01-04
# 4   2000-01-05
# 5   2000-01-06
# 6   2000-01-07
# dtype: datetime64[ns]

# %%
import csv
f = open('Desktop/ex7.csv')
reader = csv.reader(f)
reader

# %%
for line in reader:
    print(line)
# Out:
# ['a', 'b', 'c']
# ['1', '2', '3']
# ['1', '2', '3']

# %%
with open('Desktop/ex7.csv')as f:
    lines = list(csv.reader(f))
lines
# Out:
# [['a', 'b', 'c'], ['1', '2', '3'], ['1', '2', '3']]

# %%
header,values = lines[0],lines[1:]
data_dict = {h: v for h, v in zip(header,zip(*values))}
data_dict
# Out:
# {'a': ('1', '1'), 'b': ('2', '2'), 'c': ('3', '3')}

# %%
pd.DataFrame(data_dict)
# Out:
#    a  b  c
# 0  1  2  3
# 1  1  2  3

# %%
frame = pd.read_csv('Desktop/exl.csv')
frame
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
frame.to_pickle('Desktop/frame_pickle')

# %%
pd.read_pickle('Desktop/frame_pickle')
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
frame = pd.DataFrame({'a':np.random.randn(100)})
store = pd.HDFStore('mydata.h5')
store['obj1'] = frame
store['obj1_col'] = frame['a']
store
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: mydata.h5

# %%
store['obj1']
# Out:
#            a
# 0   1.094895
# 1   0.308768
# 2  -2.282354
# 3  -0.461834
# 4   2.156316
# 5   0.782214
# 6  -0.075467
# 7   0.936951
# 8  -2.341250
# 9  -1.906601
# 10 -0.464185
# 11 -0.915738
# 12 -0.055533
# 13 -1.066454
# 14  0.117572
# 15  1.195565
# 16 -0.604388
# 17 -1.046036
# 18  0.170789
# 19 -0.230886
# 20  0.817162
# 21 -0.563788
# 22 -0.336326
# 23  0.390028
# 24  1.367070
# 25 -1.757159
# 26  1.521660
# 27 -0.564163
# 28 -1.783646
# 29  0.959420
# ..       ...
# 70 -2.036501
# 71 -0.118911
# 72 -1.092669
# 73 -0.556448
# 74 -0.122640
# 75  0.908762
# 76  0.178604
# 77 -0.897637
# 78 -0.283394
# 79  0.654591
# 80 -0.665089
# 81 -0.253595
# 82 -0.531474
# 83 -1.263141
# 84 -1.807282
# 85 -0.643664
# 86 -1.117298
# 87  0.266138
# 88  0.999608
# 89  0.110584
# 90 -0.334138
# 91 -2.712603
# 92 -0.358925
# 93  1.503166
# 94  2.623338
# 95 -2.750732
# 96  0.526697
# 97  0.408487
# 98 -0.196550
# 99  1.322877
#
# [100 rows x 1 columns]

# %%
import requests
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
resp.status_code
# Out:
# 200

# %%
data = resp.json()
data[0]['title']
# Out:
# 'BUG: add back check for MultiIndex case and take_split_path'

# %%
issues = pd.DataFrame(data,columns=['number','title','labels','state'])
issues
# Out:
#     number                                              title  \
# 0    27855  BUG: add back check for MultiIndex case and ta...
# 1    27853  Error dividing Dataframe by Series but only wh...
# 2    27852   DOC:add append example in to_excel documentation
# 3    27851                         DOC: Add CoC to the README
# 4    27850  read_excel throws XLRD error when used in a fo...
# 5    27849    CLN: op-->opname in Categorical _cat_compare_op
# 6    27848  Series.str.extract not return pandas.Index object
# 7    27847                  TST: parametrize arithmetic tests
# 8    27846  BUG: boxplot does not work when data has datet...
# 9    27845                         CI: pytest, xdist versions
# 10   27844           DOC: GroupBy.head()/tail() documentation
# 11   27841  ValueError when casting 1d data to MultiIndex ...
# 12   27840    PERF: Break reference cycle for all Index types
# 13   27838                             Parametrize JSON tests
# ...

# %%
issues.to_excel('Desktop/ex2.xlsx')
